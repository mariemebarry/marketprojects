# %%
# Marieme Barry - Assignment 1

# %%
# importing pandas package
import pandas as pd

# %%
# load S&P data into a dataframe and use symbol as index of data
filename = "SP500_Constituents_20230101.csv"
dfsp = pd.read_csv(filename, index_col="Symbol")

# %%
# display the first row of data
dfsp.head(1)
# Out:
#        Security SEC filings  GICS Sector         GICS Sub-Industry  \
# Symbol
# MMM          3M     reports  Industrials  Industrial Conglomerates
#
#         Headquarters Location Date first added    CIK Founded
# Symbol
# MMM     Saint Paul, Minnesota       1976-08-09  66740    1902

# %%
# determine how many rows are in the data (answer: 503 based on output)
len(dfsp)
# Out:
# 503

# %%
# which columns have missing values? (answer: there are missing values in the date first added column)
dfsp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 503 entries, MMM to ZTS
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Security               503 non-null    object
#  1   SEC filings            503 non-null    object
#  2   GICS Sector            503 non-null    object
#  3   GICS Sub-Industry      503 non-null    object
#  4   Headquarters Location  503 non-null    object
#  5   Date first added       458 non-null    object
#  6   CIK                    503 non-null    int64
#  7   Founded                503 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 35.4+ KB

# %%
# use loc[] to find info on Apple (AAPL ticker)
dfsp.loc["AAPL"]
# Out:
# Security                                                 Apple Inc.
# SEC filings                                                 reports
# GICS Sector                                  Information Technology
# GICS Sub-Industry        Technology Hardware, Storage & Peripherals
# Headquarters Location                         Cupertino, California
# Date first added                                         1982-11-30
# CIK                                                          320193
# Founded                                                        1977
# Name: AAPL, dtype: object

# %%
# what are the distinct values within the column 'GICS Sector'? 

# Categories: Comm Services, Consumer Discretionary, Consumer Staples, Energy, Financials, Healthcare, Industrials,
# Info Tech, Materials, Real Estate, Utilities

pd.Series(dfsp['GICS Sector'].unique())
# Out:
# 0                Industrials
# 1                Health Care
# 2     Information Technology
# 3     Communication Services
# 4           Consumer Staples
# 5     Consumer Discretionary
# 6                  Utilities
# 7                 Financials
# 8                  Materials
# 9                Real Estate
# 10                    Energy
# dtype: object

# %%
# how many stocks are there in each of the GICS Sectors?

# Energy: 23
# Comm Services: 25
# Materials: 29
# Utilities: 30
# Real Estate: 31
# Consumer Staples: 33
# Consumer Discretionary: 56
# Healthcare: 63
# Financials: 67
# Industrials: 70
# IT: 76

# Total: 503

dfsp['GICS Sector'].value_counts(ascending=True)
# Out:
# Energy                    23
# Communication Services    25
# Materials                 29
# Utilities                 30
# Real Estate               31
# Consumer Staples          33
# Consumer Discretionary    56
# Health Care               63
# Financials                67
# Industrials               70
# Information Technology    76
# Name: GICS Sector, dtype: int64

# %%
# use a filter expression to display the rows where the stock is in the energy sector

dfEnergy = dfsp[dfsp["GICS Sector"] == "Energy"]
dfEnergy
# Out:
#                          Security SEC filings GICS Sector  \
# Symbol
# APA               APA Corporation     reports      Energy
# BKR                  Baker Hughes     reports      Energy
# CVX           Chevron Corporation     reports      Energy
# COP                ConocoPhillips     reports      Energy
# CTRA                      Coterra     reports      Energy
# DVN                  Devon Energy     reports      Energy
# FANG           Diamondback Energy     reports      Energy
# EOG                 EOG Resources     reports      Energy
# EQT                           EQT     reports      Energy
# XOM                    ExxonMobil     reports      Energy
# HAL                   Halliburton     reports      Energy
# HES              Hess Corporation     reports      Energy
# KMI                 Kinder Morgan     reports      Energy
# MRO                  Marathon Oil     reports      Energy
# MPC            Marathon Petroleum     reports      Energy
# ...

# %%
# Use sort_values() to order to data for Energy stocks, sorting based on the 'Date first added'.
# What company was added first, what company was added most recently?

# Halliburton (HAL ticker) was added first, and Targa Resources was added most recently.
# Note: VLO ticker displayed NaN value for date first added.

dfEnergy.sort_values('Date first added', ascending=True)
# Out:
#                          Security SEC filings GICS Sector  \
# Symbol
# HAL                   Halliburton     reports      Energy
# CVX           Chevron Corporation     reports      Energy
# COP                ConocoPhillips     reports      Energy
# XOM                    ExxonMobil     reports      Energy
# SLB                  Schlumberger     reports      Energy
# WMB            Williams Companies     reports      Energy
# OXY          Occidental Petroleum     reports      Energy
# HES              Hess Corporation     reports      Energy
# MRO                  Marathon Oil     reports      Energy
# APA               APA Corporation     reports      Energy
# DVN                  Devon Energy     reports      Energy
# EOG                 EOG Resources     reports      Energy
# CTRA                      Coterra     reports      Energy
# PXD     Pioneer Natural Resources     reports      Energy
# OKE                         ONEOK     reports      Energy
# ...

# %%
# For the full set of stocks, using isna() and column selection,
# display the Symbol, Security, and Founded for those stocks that are missing data for date first added.

dfspDFA[dfspDFA["Date first added"].isna()]
# Out:
#                         Security Date first added           Founded
# Symbol
# AMD                          AMD              NaN              1969
# ED           Consolidated Edison              NaN              1823
# GLW                 Corning Inc.              NaN              1851
# DHR          Danaher Corporation              NaN              1969
# DRI           Darden Restaurants              NaN              1938
# D                Dominion Energy              NaN              1983
# ETN            Eaton Corporation              NaN              1911
# FITB            Fifth Third Bank              NaN              1858
# FE                   FirstEnergy              NaN              1997
# BEN           Franklin Templeton              NaN              1947
# FCX             Freeport-McMoRan              NaN              1912
# GE              General Electric              NaN              1892
# HUM                       Humana              NaN              1961
# ...
