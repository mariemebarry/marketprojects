# %%
# Marieme Barry
# Advanced Python for Business

# Equity selected: Google (Ticker: GOOG)

# %%
# import pandas package; use pandas read_excel() to read the .xlsx data into a pandas DataFrame

import pandas as pd
df = pd.read_excel('GOOG.xlsx')
df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2022-02-09  140.849747  142.175507  140.376999  141.453003  141.453003
# 1   2022-02-10  139.500000  141.431000  138.050003  138.602493  138.602493
# 2   2022-02-11  138.750000  139.283249  133.288498  134.130005  134.130005
# 3   2022-02-14  133.365494  136.166504  133.302002  135.300003  135.300003
# 4   2022-02-15  137.471497  137.899994  135.539505  136.425507  136.425507
# ..         ...         ...         ...         ...         ...         ...
# 246 2023-02-02  106.790001  108.820000  106.540001  108.800003  108.800003
# 247 2023-02-03  103.510002  108.019997  103.300003  105.220001  105.220001
# 248 2023-02-06  102.684998  104.699997  102.209999  103.470001  103.470001
# 249 2023-02-07  103.629997  108.669998  103.547997  108.040001  108.040001
# 250 2023-02-08  102.690002  103.580002   98.455002  100.000000  100.000000
#
#        Volume
# 0    28628000
# 1    33018000
# 2    38808000
# ...

# %%
# Using the pandas DataFrame created in previous set, calculate and append a column for daily returns. Use AdjClose 
# prices when calculating daily returns. The pandas method pct_change() can be used to calculate daily returns.

df['Returns'] = ((df[['Open', 'Adj Close']].pct_change(axis=1)['Adj Close']) * 100).round(2).map(str) + '%'
df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2022-02-09  140.849747  142.175507  140.376999  141.453003  141.453003
# 1   2022-02-10  139.500000  141.431000  138.050003  138.602493  138.602493
# 2   2022-02-11  138.750000  139.283249  133.288498  134.130005  134.130005
# 3   2022-02-14  133.365494  136.166504  133.302002  135.300003  135.300003
# 4   2022-02-15  137.471497  137.899994  135.539505  136.425507  136.425507
# ..         ...         ...         ...         ...         ...         ...
# 246 2023-02-02  106.790001  108.820000  106.540001  108.800003  108.800003
# 247 2023-02-03  103.510002  108.019997  103.300003  105.220001  105.220001
# 248 2023-02-06  102.684998  104.699997  102.209999  103.470001  103.470001
# 249 2023-02-07  103.629997  108.669998  103.547997  108.040001  108.040001
# 250 2023-02-08  102.690002  103.580002   98.455002  100.000000  100.000000
#
#        Volume Returns
# 0    28628000   0.43%
# ...

# %%
# create a histogram for the daily returns calculated in step A.3, using pandas or matplotlib

df['Returns'] = df['Returns'].str.rstrip('%').astype('float') / 100.0
df.Returns.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
